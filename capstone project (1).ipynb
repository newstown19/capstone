# %%
import pandas as pd
import numpy as np

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
df_sfpd=pd.read_csv("C:/Users/rohan/Downloads/sfpd_2016.csv")
df_nypd=pd.read_csv("C:/Users/rohan/Downloads/NYPD_Complaint_Data_Current_YTD.csv")

# %%
df=df_sfpd.head(1000)

# %%
df_sfpd.describe
# Out:
# <bound method NDFrame.describe of         IncidntNum                Category  \
# 0        100475254                 Assault
# 1        100475254                Warrants
# 2        100475254            Non-criminal
# 3         11351210          Missing Person
# 4        120789988          Missing Person
# 5        140776777                 Robbery
# 6        140776777                 Assault
# 7        140776777            Non-criminal
# 8        140608681                 Robbery
# 9        140608681          Other Offenses
# 10       140608681                Warrants
# 11       140776777                 Robbery
# 12       140776777                 Assault
# 13       140776777                 Assault
# 14       140776777          Other Offenses
# 15       130419460                 Assault
# 16       130419460             Weapon Laws
# 17       130419460          Other Offenses
# 18       130551379                 Assault
# 19       130551379            Non-criminal
# ...

# %%
df_sfpd["Category"]
# Out:
# 0                        Assault
# 1                       Warrants
# 2                   Non-criminal
# 3                 Missing Person
# 4                 Missing Person
# 5                        Robbery
# 6                        Assault
# 7                   Non-criminal
# 8                        Robbery
# 9                 Other Offenses
# 10                      Warrants
# 11                       Robbery
# 12                       Assault
# 13                       Assault
# 14                Other Offenses
# 15                       Assault
# 16                   Weapon Laws
# 17                Other Offenses
# 18                       Assault
# 19                  Non-criminal
# 20                Other Offenses
# 21                         Fraud
# 22                Other Offenses
# 23                      Warrants
# 24                 Larceny/Theft
# 25                      Warrants
# 26                 Larceny/Theft
# 27                       Robbery
# ...

# %%
df_nypd.describe
# Out:
# <bound method NDFrame.describe of         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0        736216184   09/30/2016     23:25:00   09/30/2016     23:25:00
# 1        294332956   09/30/2016     23:16:00   09/30/2016     23:21:00
# 2        852981427   09/30/2016     23:00:00   09/30/2016     23:05:00
# 3        369976063   09/30/2016     23:00:00          NaN          NaN
# 4        117213771   09/30/2016     23:00:00   09/30/2016     23:10:00
# 5        535504374   09/30/2016     22:55:00   09/30/2016     23:15:00
# 6        457718282   09/30/2016     22:51:00          NaN          NaN
# 7        169644942   09/30/2016     22:48:00   09/30/2016     22:50:00
# 8        814258815   09/30/2016     22:45:00          NaN          NaN
# 9        589253624   09/30/2016     22:45:00   09/30/2016     22:50:00
# 10       585217984   09/30/2016     22:45:00   09/30/2016     23:05:00
# 11       443296108   09/30/2016     22:45:00   09/30/2016     22:50:00
# ...

# %%
df_nypd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361740 entries, 0 to 361739
# Data columns (total 24 columns):
# CMPLNT_NUM           361740 non-null int64
# CMPLNT_FR_DT         361740 non-null object
# CMPLNT_FR_TM         361740 non-null object
# CMPLNT_TO_DT         299442 non-null object
# CMPLNT_TO_TM         299590 non-null object
# RPT_DT               361740 non-null object
# KY_CD                361740 non-null int64
# OFNS_DESC            361702 non-null object
# PD_CD                361477 non-null float64
# PD_DESC              361477 non-null object
# CRM_ATPT_CPTD_CD     361740 non-null object
# LAW_CAT_CD           361740 non-null object
# JURIS_DESC           361740 non-null object
# BORO_NM              361740 non-null object
# ADDR_PCT_CD          361739 non-null float64
# LOC_OF_OCCUR_DESC    288401 non-null object
# PREM_TYP_DESC        360326 non-null object
# PARKS_NM             3921 non-null object
# HADEVELOPT           18696 non-null object
# ...

# %%
df_nypd["OFNS_DESC"]
# Out:
# 0                      DANGEROUS WEAPONS
# 1           ASSAULT 3 & RELATED OFFENSES
# 2                        DANGEROUS DRUGS
# 3                      DANGEROUS WEAPONS
# 4                          HARRASSMENT 2
# 5                      DANGEROUS WEAPONS
# 6                      DANGEROUS WEAPONS
# 7                        DANGEROUS DRUGS
# 8                        DANGEROUS DRUGS
# 9                        DANGEROUS DRUGS
# 10          ASSAULT 3 & RELATED OFFENSES
# 11                               ROBBERY
# 12          ASSAULT 3 & RELATED OFFENSES
# 13                     DANGEROUS WEAPONS
# 14        CRIMINAL MISCHIEF & RELATED OF
# 15                         HARRASSMENT 2
# 16                         HARRASSMENT 2
# 17        CRIMINAL MISCHIEF & RELATED OF
# 18          ASSAULT 3 & RELATED OFFENSES
# 19                       DANGEROUS DRUGS
# 20               MISCELLANEOUS PENAL LAW
# 21                         HARRASSMENT 2
# 22                         PETIT LARCENY
# ...

# %%
df_sfpd["Category"]
# Out:
# 0                        Assault
# 1                       Warrants
# 2                   Non-criminal
# 3                 Missing Person
# 4                 Missing Person
# 5                        Robbery
# 6                        Assault
# 7                   Non-criminal
# 8                        Robbery
# 9                 Other Offenses
# 10                      Warrants
# 11                       Robbery
# 12                       Assault
# 13                       Assault
# 14                Other Offenses
# 15                       Assault
# 16                   Weapon Laws
# 17                Other Offenses
# 18                       Assault
# 19                  Non-criminal
# 20                Other Offenses
# 21                         Fraud
# 22                Other Offenses
# 23                      Warrants
# 24                 Larceny/Theft
# 25                      Warrants
# 26                 Larceny/Theft
# 27                       Robbery
# ...

# %%
df_nypd.replace("",np.nan,inplace=True)

# %%
missing=df_nypd.isnull()
#print(missing.head())
for columns in missing.columns.values:
    print(missing[columns].value_counts())
    print("")
# Out:
# False    361740
# Name: CMPLNT_NUM, dtype: int64
#
# False    361740
# Name: CMPLNT_FR_DT, dtype: int64
#
# False    361740
# Name: CMPLNT_FR_TM, dtype: int64
#
# False    299442
# True      62298
# Name: CMPLNT_TO_DT, dtype: int64
#
# False    299590
# True      62150
# Name: CMPLNT_TO_TM, dtype: int64
#
# False    361740
# Name: RPT_DT, dtype: int64
#
# False    361740
# Name: KY_CD, dtype: int64
#
# False    361702
# True         38
# Name: OFNS_DESC, dtype: int64
#
# False    361477
# True        263
# Name: PD_CD, dtype: int64
#
# False    361477
# True        263
# Name: PD_DESC, dtype: int64
#
# False    361740
# Name: CRM_ATPT_CPTD_CD, dtype: int64
#
# False    361740
# Name: LAW_CAT_CD, dtype: int64
#
# False    361740
# Name: JURIS_DESC, dtype: int64
#
# False    361740
# Name: BORO_NM, dtype: int64
#
# False    361739
# True          1
# Name: ADDR_PCT_CD, dtype: int64
#
# False    288401
# True      73339
# Name: LOC_OF_OCCUR_DESC, dtype: int64
#
# False    360326
# ...

# %%
df_nypd
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0        736216184   09/30/2016     23:25:00   09/30/2016     23:25:00
# 1        294332956   09/30/2016     23:16:00   09/30/2016     23:21:00
# 2        852981427   09/30/2016     23:00:00   09/30/2016     23:05:00
# 3        369976063   09/30/2016     23:00:00          NaN          NaN
# 4        117213771   09/30/2016     23:00:00   09/30/2016     23:10:00
# 5        535504374   09/30/2016     22:55:00   09/30/2016     23:15:00
# 6        457718282   09/30/2016     22:51:00          NaN          NaN
# 7        169644942   09/30/2016     22:48:00   09/30/2016     22:50:00
# 8        814258815   09/30/2016     22:45:00          NaN          NaN
# 9        589253624   09/30/2016     22:45:00   09/30/2016     22:50:00
# 10       585217984   09/30/2016     22:45:00   09/30/2016     23:05:00
# 11       443296108   09/30/2016     22:45:00   09/30/2016     22:50:00
# ...

# %%
df_nypd.dropna(subset=["Lat_Lon"], axis=0, inplace = True)

# %%
df_nypd.reset_index(drop = True, inplace = True)

# %%
df_nypd.dropna(subset=["OFNS_DESC"], axis=0, inplace = True)

# %%
df_nypd.reset_index(drop = True, inplace = True)

# %%
df_nypd["OFNS_DESC"]
# Out:
# 0                      DANGEROUS WEAPONS
# 1           ASSAULT 3 & RELATED OFFENSES
# 2                        DANGEROUS DRUGS
# 3                      DANGEROUS WEAPONS
# 4                          HARRASSMENT 2
# 5                      DANGEROUS WEAPONS
# 6                      DANGEROUS WEAPONS
# 7                        DANGEROUS DRUGS
# 8                        DANGEROUS DRUGS
# 9                        DANGEROUS DRUGS
# 10          ASSAULT 3 & RELATED OFFENSES
# 11                               ROBBERY
# 12          ASSAULT 3 & RELATED OFFENSES
# 13                     DANGEROUS WEAPONS
# 14        CRIMINAL MISCHIEF & RELATED OF
# 15                         HARRASSMENT 2
# 16                         HARRASSMENT 2
# 17        CRIMINAL MISCHIEF & RELATED OF
# 18          ASSAULT 3 & RELATED OFFENSES
# 19                       DANGEROUS DRUGS
# 20               MISCELLANEOUS PENAL LAW
# 21                         HARRASSMENT 2
# 22                         PETIT LARCENY
# ...

# %%
df_nypd["OFNS_DESC"].value_counts()
# Out:
# PETIT LARCENY                           60849
# HARRASSMENT 2                           49905
# ASSAULT 3 & RELATED OFFENSES            39976
# CRIMINAL MISCHIEF & RELATED OF          37618
# GRAND LARCENY                           32561
# OFF. AGNST PUB ORD SENSBLTY &           17401
# DANGEROUS DRUGS                         17188
# FELONY ASSAULT                          15869
# ROBBERY                                 11472
# MISCELLANEOUS PENAL LAW                 10537
# BURGLARY                                 9635
# DANGEROUS WEAPONS                        8058
# OFFENSES AGAINST PUBLIC ADMINI           6911
# VEHICLE AND TRAFFIC LAWS                 4950
# GRAND LARCENY OF MOTOR VEHICLE           4767
# FORGERY                                  4585
# INTOXICATED & IMPAIRED DRIVING           4423
# THEFT-FRAUD                              3703
# CRIMINAL TRESPASS                        3001
# FRAUDS                                   2626
# ...

# %%
df_nypd
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0        736216184   09/30/2016     23:25:00   09/30/2016     23:25:00
# 1        294332956   09/30/2016     23:16:00   09/30/2016     23:21:00
# 2        852981427   09/30/2016     23:00:00   09/30/2016     23:05:00
# 3        369976063   09/30/2016     23:00:00          NaN          NaN
# 4        117213771   09/30/2016     23:00:00   09/30/2016     23:10:00
# 5        535504374   09/30/2016     22:55:00   09/30/2016     23:15:00
# 6        457718282   09/30/2016     22:51:00          NaN          NaN
# 7        169644942   09/30/2016     22:48:00   09/30/2016     22:50:00
# 8        814258815   09/30/2016     22:45:00          NaN          NaN
# 9        589253624   09/30/2016     22:45:00   09/30/2016     22:50:00
# 10       585217984   09/30/2016     22:45:00   09/30/2016     23:05:00
# 11       443296108   09/30/2016     22:45:00   09/30/2016     22:50:00
# ...

# %%
df=pd.DataFrame(columns=df_nypd.values)

# %%
df_nypd.values
# Out:
# array([[736216184, '09/30/2016', '23:25:00', ..., 40.837376359000004,
#         -73.887760929, '(40.837376359, -73.887760929)'],
#        [294332956, '09/30/2016', '23:16:00', ..., 40.661204871,
#         -73.950686652, '(40.661204871, -73.950686652)'],
#        [852981427, '09/30/2016', '23:00:00', ..., 40.816872438000004,
#         -73.850684927, '(40.816872438, -73.850684927)'],
#        ...,
#        [640212578, '01/01/2015', '00:30:00', ..., 40.754199468,
#         -73.832962523, '(40.754199468, -73.832962523)'],
#        [496500431, '06/30/2014', '12:00:00', ..., 40.883776851,
#         -73.90783692800001, '(40.883776851, -73.907836928)'],
#        [256379572, '12/31/2001', '16:00:00', ..., 40.683616638000004,
#         -73.980416007, '(40.683616638, -73.980416007)']], dtype=object)

# %%
df_sfpd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104813 entries, 0 to 104812
# Data columns (total 13 columns):
# IncidntNum    104813 non-null int64
# Category      104813 non-null object
# Descript      104813 non-null object
# DayOfWeek     104813 non-null object
# Date          104813 non-null object
# Time          104813 non-null object
# PdDistrict    104812 non-null object
# Resolution    104813 non-null object
# Address       104813 non-null object
# X             104813 non-null float64
# Y             104813 non-null float64
# Location      104813 non-null object
# PdId          104813 non-null int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 6.8+ MB

# %%
df_sfpd["Category"].value_counts()
# Out:
# Larceny/Theft                  27640
# Other Offenses                 13776
# Non-criminal                   12737
# Assault                         9513
# Vandalism                       5861
# Vehicle Theft                   4450
# Warrants                        4304
# Burglary                        4114
# Suspicious Occ                  3879
# Drug/Narcotic                   3101
# Missing Person                  2935
# Robbery                         2314
# Fraud                           1867
# Secondary Codes                 1243
# Trespass                        1229
# Weapon Laws                     1129
# Stolen Property                  656
# Sex Offenses, Forcible           647
# Recovered Vehicle                518
# Prostitution                     450
# Disorderly Conduct               443
# Forgery/Counterfeiting           434
# Drunkenness                      342
# Driving Under The Influence      252
# Arson                            207
# ...

# %%
dfnypd=pd.read_excel("C:/Users/rohan/Desktop/nypd.xlsx")

# %%
# %matplotlib inline

# %%
dfnypd.set_index("Violation",inplace=True)

# %%
dfnypd["Count"].plot(kind="bar",figsize=(20,20),width=.9,fontsize=10) #incidents of criminal offenses in city of New York

# %%
dfsfpd=pd.read_excel("C:/Users/rohan/Desktop/sfpd.xlsx")

# %%
dfsfpd.describe
dfsfpd.set_index("Violation",inplace=True)

# %%
dfsfpd["Count"].plot(kind="bar",width=.9,fontsize=13,figsize=(20,20)) #incidents in city of San francisco

# %%
import folium

# %%
san_map=folium.Map(location=[37.7749,-122.4194],zoom_start=11)
san_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(0,len(df)):                                                                           #creating marker on places of offenses
    folium.Marker([df.iloc[i]['Y'], df.iloc[i]['X']], popup=df.iloc[i]['Category']).add_to(san_map)

# %%
san_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df2=df_nypd.head(1000)

# %%
ny_map=folium.Map(location=[40.7128,-74.0060], zoom_start=11)
ny_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in range(0,len(df2)):                                                                           #creating marker on places of offenses
    folium.Marker([df2.iloc[i]['Latitude'], df2.iloc[i]['Longitude']], popup=df2.iloc[i]['OFNS_DESC']).add_to(ny_map)

# %%
ny_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
